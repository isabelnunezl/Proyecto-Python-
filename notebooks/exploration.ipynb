# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data_path = "../data/processed/cleaned_products.csv" 
df = pd.read_csv(data_path) 

print("Basic Statistics") 
print(df.describe()) 

# Histograma de precios.

plt.hist(df["price"], bins=20, edgecolor="black") 
plt.title("Distribucion de precios")
plt.xlabel("Precio") 
plt.ylabel("Frecuencia") 
plt.show() 

# Productos mas caros.

print("Productos mas Caros: ") 
highestPrice= df.nlargest(5,'price')
print(highestPrice)
# Out:
# Basic Statistics
#             price
# count     3.00000
# mean    972.48000
# std     433.74015
# min     488.78000
# 25%     795.30500
# 50%    1101.83000
# 75%    1214.33000
# max    1326.83000
# Productos mas Caros:
#                title                                        description  \
# 1  Hewlett Packar...  Hewlett Packard ProBook 640 G3, 14" FHD, Core ...
# 0  Asus ROG Strix...  Apple MacBook Air 13.3", Core i5 1.8GHz, 8GB, ...
# 2     Dell Vostro 15  Dell Vostro 15 (3568) Black, 15.6" FHD, Core i...
#
#      price
# 1  1326.83
# 0  1101.83
# 2   488.78
